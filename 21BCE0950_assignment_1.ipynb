# %% [markdown]
# # Assignment 1

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q 1

# %%
data = {'A': np.random.random(5), 'B': np.random.random(5), 'C': np.random.random(5), 'D': np.random.random(5)}
df = pd.DataFrame(data)

# %%
df
# Out:
#           A         B         C         D
# 0  0.516033  0.803180  0.591164  0.163991
# 1  0.486567  0.114267  0.440054  0.648720
# 2  0.558197  0.464285  0.367870  0.226780
# 3  0.601567  0.613686  0.447752  0.819429
# 4  0.466237  0.727363  0.417344  0.881634

# %% [markdown]
# Q2

# %%
df.columns = ['column 1', 'column 2', 'column 3', 'column 4']
df
# Out:
#    column 1  column 2  column 3  column 4
# 0  0.516033  0.803180  0.591164  0.163991
# 1  0.486567  0.114267  0.440054  0.648720
# 2  0.558197  0.464285  0.367870  0.226780
# 3  0.601567  0.613686  0.447752  0.819429
# 4  0.466237  0.727363  0.417344  0.881634

# %% [markdown]
# Q3

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    column 1  column 2  column 3  column 4
# 0  0.516033  0.803180  0.591164  0.163991
# 1  0.486567  0.114267  0.440054  0.648720
# 2  0.558197  0.464285  0.367870  0.226780
# 3  0.601567  0.613686  0.447752  0.819429
# 4  0.466237  0.727363  0.417344  0.881634>

# %% [markdown]
# Q4

# %%
df.isnull()
# Out:
#    column 1  column 2  column 3  column 4
# 0     False     False     False     False
# 1     False     False     False     False
# 2     False     False     False     False
# 3     False     False     False     False
# 4     False     False     False     False

# %%
df.dtypes
# Out:
# column 1    float64
# column 2    float64
# column 3    float64
# column 4    float64
# dtype: object

# %% [markdown]
# Q5

# %%
df.loc[:, ['column 1', 'column 2']]
# Out:
#    column 1  column 2
# 0  0.516033  0.803180
# 1  0.486567  0.114267
# 2  0.558197  0.464285
# 3  0.601567  0.613686
# 4  0.466237  0.727363

# %%
df.iloc[:,[0,1]]
# Out:
#    column 1  column 2
# 0  0.516033  0.803180
# 1  0.486567  0.114267
# 2  0.558197  0.464285
# 3  0.601567  0.613686
# 4  0.466237  0.727363
